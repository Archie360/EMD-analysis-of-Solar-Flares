# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import emd
from statistics import mean
from scipy import signal, ndimage
import math

# %%
from scipy.optimize import curve_fit
import matplotlib.patches as ptc
from numpy.polynomial import Polynomial
from astropy.io import fits
from scipy.io import readsav
import os
import scipy.linalg as la
from scipy.stats import sem
from scipy import asarray as ar,exp

# %%
import scienceplots
plt.style.use(['science','notebook','grid'])

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
name="16_0134522301/rgs12o12_b50_16_0134522301_decay2.dat"
dir_=name.split('/')[0]
# !mkdir results/$dir_
datContent = [i.strip().split() for i in 
              open(name).readlines()]

datContent = datContent[5:]

t= np.array(datContent)[:,0]
x1= np.array(datContent)[:,1]
e= np.array(datContent)[:,2]
# Out:
# mkdir: results/16_0134522301: File exists

# %%
dir_
# Out:
# '16_0134522301'

# %%
def exp(t,c1,m1,c2,m2):
    return c1*np.exp(-t/m1) + c2*np.exp(-t/m2)

# %%
def scaling(t,c,m):
    return c*t**m

# %%
def ds(t,A,P,tau,phi,t0):
        return A*exp(-(t-t0)/tau)*np.sin(2*np.pi*(t-t0)/P -phi)

# %%
def bm(List):
    mins=[]
    maxs=[]
    for n, i in enumerate(List[1:-1]):
            if List[n] < List[n-1] and List[n] < List[n+1]:
                mins.append(List[n])
            elif List[n] > List[n-1] and i> List[n+1]:
                maxs.append(List[n])
    return len(mins)+len(maxs)

# %%
def log_fit(xi,yi,x,deg):  
    coefficients = np.polyfit(np.log10(xi), np.log10(yi), deg)
    polynomial = np.poly1d(coefficients)
    log10_y_fit = polynomial(np.log10(x))  # <-- Changed

    L=[]
    L.append(x)
    L.append(10**log10_y_fit)
    return L

# %%
def fit(xi,yi,x,deg,col='green'):  
    coefficients = np.polyfit((xi), (yi), deg)
    polynomial = np.poly1d(coefficients)
    log10_y_fit = polynomial((x))  # <-- Changed

    L=[]
    L.append(x)
    L.append(log10_y_fit)
    return L

# %%
def spread(x,k,N):
    return x+(k*(math.sqrt(2/N))*(np.e**(x/2))),x-(k*(math.sqrt(2/N))*(np.e**(x/2)))

# %%
def bypart(xi,yi,s,e,k) : 
    lf= log_fit(xi[s:e],yi[s:e],np.linspace(xi[s],xi[e],len(x)),1)
    slope= (lf[1][1]-lf[1][0])/(lf[0][1]-lf[0][0])
    print(slope)

    plt.title('Least square fit')
    plt.plot(lf[0],lf[1],'--',color='black',linewidth=1)
    U,L=[],[]
    
    for i in range(len(lf[0])):
        u,l=spread(lf[1][i],k,len(lf[1])*10)
        L.append((l))
        U.append((u))
    
    
    plt.plot((lf[0])[:],U[:],c='black',linestyle='--')
    plt.plot((lf[0])[:],L[:],c='black',linestyle='--')
    
    plt.scatter((xi),(yi),color='blue',s=80)


    plt.loglog()
    plt.ylim(1e-3)

# %%
t_,x_,e_=[],[],[]
for i in range(len(t)):
    t_.append(float(t[i]))
    x_.append(float(x1[i]))    
    e_.append(float(e[i]))    
    
t_ = np.array(t_)
x_ = np.array(x_)
e_ = np.array(e_)

# %%
dt= 50/60
fs= 1/dt

# %%
x=x_[:-2]
t1=t_[:-2]

# %%
t1=t1/60

# %%
len(t1)
# Out:
# 323

# %%
plt.plot(t1,x)

# %%
popt, pcov = curve_fit(exp,t1, x,bounds=(0,[1e3,1e3,1e3,1e3] ))
plt.plot(t1,x)
plt.plot(t1, exp(t1, *popt), color='red')
# plt.savefig('results/'+dir_+'/Texp.png')

# %%
c1,m1,c2,m2=popt

# %%
Texp=exp(t1, *popt)
x1=x-Texp
x1=x

# %%
plt.plot(t1,x1)
plt.title('F0-Texp')
# plt.savefig('results/'+dir_+'/F0-Texp.png')
# Out:
# Text(0.5, 1.0, 'F0-Texp')

# %%
len(x)
# Out:
# 323

# %%
imfm = emd.sift.mask_sift(x1)
n_imfm= len(imfm[0,:])
# Out:
#  Inputs samples (323) is small for specified max_imfs (9) very likely that 7 or fewer imfs are returned

# %%
plt.figure(figsize=(12,12))

for i in range(n_imfm):
    plt.subplot(n_imfm,2,i +1)
    plt.subplots_adjust(wspace=0, hspace=0)
    
    plt.plot(t1,imfm[:,i])
# plt.savefig('results/'+dir_+'/imfs.png')

# %%
trend=int(input('enter trend'))
# Out:
# enter trend 6

# %%
Temd=np.zeros(len(imfm[:,0]))
for i in range(trend,n_imfm):
    Temd=Temd+imfm[:,i]
    
plt.plot(t1,x1,c='black')
plt.plot(t1,Temd,c='red')
plt.title('Temd')
# plt.savefig('results/'+dir_+'/Temd.png')
# Out:
# Text(0.5, 1.0, 'Temd')

# %%
x2= x1-Temd

# %%
# plt.figure(figsize=(12,4))
plt.plot(t1,x2)
plt.plot(t1,imfm[:,5],linewidth=3,c='brown')
plt.title('F0-Texp-Temd')
# plt.savefig('results/'+dir_+'/correlated.png')
# Out:
# Text(0.5, 1.0, 'F0-Texp-Temd')

# %%
Em=[]
Pm=[]
for i in range(n_imfm-1):
    E=mean(imfm[:,i]**2)
    P=len(imfm[:,i])/bm(imfm[:,i])
    Em.append(E)
    Pm.append(P)
    
Ex=mean(x**2)
Px=2*len(x)/bm(x)

Em=np.array(Em)
Pm=np.array(Pm)

# %%
Pm
# Out:
# array([  2.69166667,   7.17777778,  13.45833333,  24.84615385,
#         53.83333333, 107.66666667, 323.        ])

# %%
bypart(Pm,Em,0,n_imfm-2,.39)
plt.axvline(x=.4*len(x),linestyle='--')
# plt.ylim(1e-3,1e1)
# bypart(Pm,Em,2,trend)
# plt.savefig('results/'+dir_+'/modal.png')
# plt.semilogx(1/fxx,10**((pxx-9)/3))
# Out:
# -0.0041983478439065565

# %%
fxx, pxx =sp.signal.welch(x2,fs,detrend='linear',window='boxcar', nperseg=len(x2))
non_zero_indices = fxx != 0
period = 1 / fxx[non_zero_indices]
popt, pcov = curve_fit(scaling,period, pxx[non_zero_indices])
print(popt)

sig=np.std(pxx)
prd=np.linspace(min(period),max(period),1000)

plt.plot(period,pxx[non_zero_indices],c='black')


plt.axvline(x=.4*len(x),linestyle='--')

lf=log_fit(period,pxx[non_zero_indices],prd,1)
plt.plot(lf[0],lf[1],color='red')
# plt.plot(lf[0], lf[1]*(1*sig),color='red',linestyle='--')
# plt.plot(lf[0], lf[1]*(2*sig),color='red',linestyle='--')
plt.plot(lf[0], lf[1]*(3/sig),color='red',linestyle='--')
plt.loglog()
# plt.savefig('results/'+dir_+'/fft.png')
# Out:
# [0.08300942 0.37332614]
# []

# %%
sig
# Out:
# 0.17728776436304416

# %%
period
# Out:
# array([269.16666667, 134.58333333,  89.72222222,  67.29166667,
#         53.83333333,  44.86111111,  38.45238095,  33.64583333,
#         29.90740741,  26.91666667,  24.46969697,  22.43055556,
#         20.70512821,  19.22619048,  17.94444444,  16.82291667,
#         15.83333333,  14.9537037 ,  14.16666667,  13.45833333,
#         12.81746032,  12.23484848,  11.70289855,  11.21527778,
#         10.76666667,  10.3525641 ,   9.9691358 ,   9.61309524,
#          9.2816092 ,   8.97222222,   8.6827957 ,   8.41145833,
#          8.15656566,   7.91666667,   7.69047619,   7.47685185,
#          7.27477477,   7.08333333,   6.9017094 ,   6.72916667,
#          6.56504065,   6.40873016,   6.25968992,   6.11742424,
#          5.98148148,   5.85144928,   5.72695035,   5.60763889,
#          5.49319728,   5.38333333,   5.27777778,   5.17628205,
#          5.07861635,   4.9845679 ,   4.89393939,   4.80654762,
#          4.72222222,   4.6408046 ,   4.56214689,   4.48611111,
#          4.41256831,   4.34139785,   4.27248677,   4.20572917,
#          4.14102564,   4.07828283,   4.01741294,   3.95833333,
#          3.90096618,   3.8452381 ,   3.79107981,   3.73842593,
#          3.68721461,   3.63738739,   3.58888889,   3.54166667,
#          3.495671  ,   3.4508547 ,   3.407173  ,   3.36458333,
#          3.32304527,   3.28252033,   3.24297189,   3.20436508,
#          3.16666667,   3.12984496,   3.09386973,   3.05871212,
#          3.02434457,   2.99074074,   2.95787546,   2.92572464,
#          2.89426523,   2.86347518,   2.83333333,   2.80381944,
#          2.77491409,   2.74659864,   2.71885522,   2.69166667,
#          2.6650165 ,   2.63888889,   2.61326861,   2.58814103,
#          2.56349206,   2.53930818,   2.51557632,   2.49228395,
#          2.46941896,   2.4469697 ,   2.42492492,   2.40327381,
#          2.3820059 ,   2.36111111,   2.34057971,   2.3204023 ,
#          2.3005698 ,   2.28107345,   2.26190476,   2.24305556,
#          2.22451791,   2.20628415,   2.18834688,   2.17069892,
#          2.15333333,   2.13624339,   2.11942257,   2.10286458,
#          2.08656331,   2.07051282,   2.05470738,   2.03914141,
#          2.02380952,   2.00870647,   1.99382716,   1.97916667,
#          1.96472019,   1.95048309,   1.93645084,   1.92261905,
#          1.90898345,   1.89553991,   1.88228438,   1.86921296,
#          1.85632184,   1.84360731,   1.83106576,   1.81869369,
#          1.8064877 ,   1.79444444,   1.78256071,   1.77083333,
#          1.75925926,   1.7478355 ,   1.73655914,   1.72542735,
#          1.71443737,   1.7035865 ,   1.69287212,   1.68229167,
#          1.67184265])

# %%
# plt.figure(figsize=(10,6))

fxx, pxx =sp.signal.welch(x2,fs,detrend='linear',window='boxcar', nperseg=len(x2))
plt.plot(1/fxx,pxx)
p0=.05
y0= -np.log(1-(1-p0)**(1/len(fxx)))*mean(pxx)
plt.axhline(y=y0,color='blue')
plt.axvline(x=.4*len(x),linestyle='--')


plt.semilogx()
plt.ylim(0,2*y0)
# plt.savefig('results/'+dir_+'/periodogram.png')
# Out:
# (0.0, 2.5524284314474657)

# %%
1/fxx
# Out:
# array([         inf, 269.16666667, 134.58333333,  89.72222222,
#         67.29166667,  53.83333333,  44.86111111,  38.45238095,
#         33.64583333,  29.90740741,  26.91666667,  24.46969697,
#         22.43055556,  20.70512821,  19.22619048,  17.94444444,
#         16.82291667,  15.83333333,  14.9537037 ,  14.16666667,
#         13.45833333,  12.81746032,  12.23484848,  11.70289855,
#         11.21527778,  10.76666667,  10.3525641 ,   9.9691358 ,
#          9.61309524,   9.2816092 ,   8.97222222,   8.6827957 ,
#          8.41145833,   8.15656566,   7.91666667,   7.69047619,
#          7.47685185,   7.27477477,   7.08333333,   6.9017094 ,
#          6.72916667,   6.56504065,   6.40873016,   6.25968992,
#          6.11742424,   5.98148148,   5.85144928,   5.72695035,
#          5.60763889,   5.49319728,   5.38333333,   5.27777778,
#          5.17628205,   5.07861635,   4.9845679 ,   4.89393939,
#          4.80654762,   4.72222222,   4.6408046 ,   4.56214689,
#          4.48611111,   4.41256831,   4.34139785,   4.27248677,
#          4.20572917,   4.14102564,   4.07828283,   4.01741294,
#          3.95833333,   3.90096618,   3.8452381 ,   3.79107981,
#          3.73842593,   3.68721461,   3.63738739,   3.58888889,
#          3.54166667,   3.495671  ,   3.4508547 ,   3.407173  ,
#          3.36458333,   3.32304527,   3.28252033,   3.24297189,
#          3.20436508,   3.16666667,   3.12984496,   3.09386973,
#          3.05871212,   3.02434457,   2.99074074,   2.95787546,
#          2.92572464,   2.89426523,   2.86347518,   2.83333333,
#          2.80381944,   2.77491409,   2.74659864,   2.71885522,
#          2.69166667,   2.6650165 ,   2.63888889,   2.61326861,
#          2.58814103,   2.56349206,   2.53930818,   2.51557632,
#          2.49228395,   2.46941896,   2.4469697 ,   2.42492492,
#          2.40327381,   2.3820059 ,   2.36111111,   2.34057971,
#          2.3204023 ,   2.3005698 ,   2.28107345,   2.26190476,
#          2.24305556,   2.22451791,   2.20628415,   2.18834688,
#          2.17069892,   2.15333333,   2.13624339,   2.11942257,
#          2.10286458,   2.08656331,   2.07051282,   2.05470738,
#          2.03914141,   2.02380952,   2.00870647,   1.99382716,
#          1.97916667,   1.96472019,   1.95048309,   1.93645084,
#          1.92261905,   1.90898345,   1.89553991,   1.88228438,
#          1.86921296,   1.85632184,   1.84360731,   1.83106576,
#          1.81869369,   1.8064877 ,   1.79444444,   1.78256071,
#          1.77083333,   1.75925926,   1.7478355 ,   1.73655914,
#          1.72542735,   1.71443737,   1.7035865 ,   1.69287212,
#          1.68229167,   1.67184265])

# %% [markdown]
# ###
