# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import emd
from statistics import mean
from scipy import signal, ndimage
import math

# %%
from scipy.optimize import curve_fit
import matplotlib.patches as ptc
from numpy.polynomial import Polynomial
from astropy.io import fits
from scipy.io import readsav
import os
import scipy.linalg as la
from scipy.stats import sem
from scipy import asarray as ar,exp

# %%
import scienceplots
plt.style.use(['science','notebook','grid'])

# %%
datContent = [i.strip().split() for i in 
              open("03_0123720301/pn_b50_03_0123720301_flare3_decay.dat").readlines()]

datContent = datContent[5:]

t= np.array(datContent)[:,0]
x1= np.array(datContent)[:,1]
e= np.array(datContent)[:,2]

# %%
t_,x_,e_=[],[],[]
for i in range(len(t)):
    t_.append(float(t[i]))
    x_.append(float(x1[i]))    
    e_.append(float(e[i]))    
    
t_ = np.array(t_)
x_ = np.array(x_)
e_ = np.array(e_)

# %%
plt.plot(t_,x_)

# %%
dt= 50/60
fs= 1/dt

# %%
x=x_
t1=t_

# %%
t1=t1/60

# %%
plt.plot(t1,x)

# %%
imfm = emd.sift.mask_sift(x)
n_imfm= len(imfm[0,:])
# Out:
#  Inputs samples (209) is small for specified max_imfs (9) very likely that 6 or fewer imfs are returned

# %%
plt.figure(figsize=(12,12))

for i in range(n_imfm):
    plt.subplot(n_imfm,2,i +1)
    plt.subplots_adjust(wspace=0, hspace=0)
    
    plt.plot(t1,imfm[:,i])

# %%
plt.plot(t1,x,c='black')
bg=np.zeros(len(imfm[:,0]))
inum=5
for i in range(inum,n_imfm):
    bg=bg+imfm[:,i]
plt.plot(t1,bg,c='red')

# %%
plt.figure(figsize=(15,6))
qpp= imfm[:,4]

plt.subplot(1,2,1)
plt.plot(t1[:-1],x[:-1]-bg[:-1])
plt.plot(t1[:-1],qpp[:-1])

plt.subplot(1,2,2)
tf=t1
plt.plot(tf,qpp)

# %%
def ds(t,A,P,tau,phi,t0):
        return A*exp(-(t-t0)/tau)*np.sin(2*np.pi*(t-t0)/P -phi)

# %%
popt, pcov = curve_fit(ds,tf, qpp,bounds=(0,[1e3,1e2,1e3,1e3,1e3] ))
# Out:
# /var/folders/gq/8wbg8lhd50b6xp31434c79mh0000gn/T/ipykernel_14357/2943167119.py:2: DeprecationWarning: scipy.exp is deprecated and will be removed in SciPy 2.0.0, use numpy.exp instead
#   return A*exp(-(t-t0)/tau)*np.sin(2*np.pi*(t-t0)/P -phi)

# %%
A,P,tau,phi,t0= popt

# %%
P,tau
# Out:
# (43.01428235007982, 48.10532816136562)

# %%
plt.plot(tf, ds(tf, *popt))
plt.plot(tf,qpp)
# plt.xlim(0,2*tau)
# plt.plot(t1,ds(t1,48.8,650.98))
# plt.plot(tf,exp(-tf/tau),'--',c='b')
# plt.plot(tf,-exp(-tf/tau),'--',c='b')
# Out:
# /var/folders/gq/8wbg8lhd50b6xp31434c79mh0000gn/T/ipykernel_14357/2943167119.py:2: DeprecationWarning: scipy.exp is deprecated and will be removed in SciPy 2.0.0, use numpy.exp instead
#   return A*exp(-(t-t0)/tau)*np.sin(2*np.pi*(t-t0)/P -phi)

# %%
def scaling(t,c,m):
    return c*(t**m)

# %%
popt, pcov = curve_fit(scaling,period, pxx[non_zero_indices])

# %%
popt
# Out:
# array([1.14908324, 0.53231855])

# %%
sig=np.std(pxx)

# %%
plt.figure(figsize = (12, 6))


fxx, pxx =sp.signal.welch(x-bg,fs,detrend='linear',window='boxcar')
plt.plot(1/fxx,pxx)
plt.axvline(x=P,c='red')

mean_plus_std = np.mean(pxx) + 2*np.std(pxx)
plt.axhline(y=mean_plus_std, color='green', linestyle='--', label='Mean + Std Line')
# plt.plot(np.linspace(min(period),max(period),1000), scaling(np.linspace(min(period),max(period),1000)*np.exp(i*sig), *popt),'--', color='red')
# plt.plot(np.linspace(min(period),max(period),1000), scaling(np.linspace(min(period),max(period),1000)*np.exp(3*sig), *popt),'--', color='red')

plt.semilogx()
# plt.loglog()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/signal/_spectral_py.py:2014: UserWarning: nperseg = 256 is greater than input length  = 209, using nperseg = 209
#   warnings.warn('nperseg = {0:d} is greater than input length '
# /var/folders/gq/8wbg8lhd50b6xp31434c79mh0000gn/T/ipykernel_14357/454955654.py:5: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(1/fxx,pxx)
# []

# %%
non_zero_indices = fxx != 0
period = 1 / fxx[non_zero_indices]

# %%
prd=np.linspace(min(period),max(period),1000)

# %%
plt.plot(period,pxx[non_zero_indices],c='blue')
plt.plot(prd, scaling(prd, *popt),'--', color='black')
plt.plot(prd, scaling(prd, *popt)*(10**(2*sig)),'--', color='red')
plt.plot(prd, scaling(prd, *popt)*(10**(1*sig)),'--', color='green')
plt.axvline(x=P,c='red')

plt.loglog()
# Out:
# []

# %%
def bm(List):
    mins=[]
    maxs=[]
    for n, i in enumerate(List[1:-1]):
            if List[n] < List[n-1] and List[n] < List[n+1]:
                mins.append(List[n])
            elif List[n] > List[n-1] and i> List[n+1]:
                maxs.append(List[n])
    return len(mins)+len(maxs)

# %%
Em=[]
Pm=[]
for i in range(n_imfm-2):
    E=mean(imfm[:,i]**2)
    P=2*len(imfm[:,i])/bm(imfm[:,i])
    Em.append(E)
    Pm.append(P)
    
Ex=mean(x**2)
Px=2*len(x)/bm(x)

Em=np.array(Em)
Pm=np.array(Pm)

# %%
plt.scatter(Pm,Em)
plt.loglog()

# %%
def log_fit(xi,yi,x,deg,col='green'):  
    coefficients = np.polyfit(np.log10(xi), np.log10(yi), deg)
    polynomial = np.poly1d(coefficients)
    log10_y_fit = polynomial(np.log10(x))  # <-- Changed

    L=[]
    L.append(x)
    L.append(10**log10_y_fit)
    return L

# %%
def fit(xi,yi,x,deg,col='green'):  
    coefficients = np.polyfit((xi), (yi), deg)
    polynomial = np.poly1d(coefficients)
    log10_y_fit = polynomial((x))  # <-- Changed

    L=[]
    L.append(x)
    L.append(log10_y_fit)
    return L

# %%
def spread(x,k,N):
    return x+(k*(math.sqrt(2/N))*(np.e**(x/2))),x-(k*(math.sqrt(2/N))*(np.e**(x/2)))

# %%
def bypart(s,e) : 
    lf= log_fit(Pm[s:e],Em[s:e],np.linspace(Pm[s],Pm[e],250),1)
    slope= (lf[1][1]-lf[1][0])/(lf[0][1]-lf[0][0])
    print(slope)

    plt.title('Least square fit')
    plt.plot((lf[0]),(lf[1]),'--',color='black',linewidth=1)
    U,L=[],[]
    for i in range(len(lf[0])):
        u,l=spread(lf[1][i],0.675,len(lf[1]))
        L.append((l))
        U.append((u))
    plt.plot((lf[0])[:-10],U[:-10],'--')
    plt.plot((lf[0])[:-10],L[:-10],'--')
    plt.scatter((Pm),(Em),color='brown')
    # plt.scatter(np.log10(Px),np.log10(Ex),color='brown')

    plt.loglog()

# %%
br=3
# bypart(br,-1)
bypart(0,br)

# %%
# IP, IF, IA = emd.spectra.frequency_transform(imfm, fs, 'nht')
# freq_range = (0, .3, 100)
# plt.figure(figsize=(10,10))

# for i in range(5):
#     plt.subplot(5,1,i+1)
#     hht_f, hht = emd.spectra.hilberthuang(IF[:,i], IA[:,i], freq_range, mode='amplitude', sum_time=False)
#     hht = ndimage.gaussian_filter(hht, 10)

#     c=plt.pcolormesh(t1, hht_f, hht, cmap='magma_r')
#     # plt.title('Hilbert-Huang Transform')
#     plt.subplots_adjust( hspace=0)
    
#     # plt.xlabel('Time (min)')
#     plt.xticks([])
#     plt.yticks=((0,.3,.3))
#     # plt.ylabel('Frequency (Hz)')
#     # plt.colorbar(c)
# plt.savefig('hibert.png')

# %%
# IP, IF, IA = emd.spectra.frequency_transform(imfm, fs, 'hilbert')
# freq_range = (0, .3, 100)
# hht_f, hht = emd.spectra.hilberthuang(IF[:,:2], IA[:,:2], freq_range, mode='amplitude', sum_time=False)
# hht = ndimage.gaussian_filter(hht, 4)
# plt.grid(False)
# c=plt.pcolormesh(t1, hht_f, hht, cmap='magma_r')

# # plt.xlim(38000)
# # plt.ylim(0,1)
