# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import emd
from statistics import mean
from scipy import signal, ndimage
import math

from scipy.optimize import curve_fit
import matplotlib.patches as ptc
from numpy.polynomial import Polynomial
from scipy.io import readsav
import os
import scipy.linalg as la
from scipy.stats import sem
from scipy import asarray as ar,exp
from functions import *

# %%
import scienceplots
plt.style.use(['science','notebook','grid'])

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
name = 'inttime_193_6Mm.txt'
datContent = [i.strip().split() for i in open(name).readlines()]
datContent = datContent[5:]

t   = np.array(datContent)[:,0]
x1  = np.array(datContent)[:,1]
# e   = np.array(datContent)[:,2]

# %%
t_,x_=[],[]
for i in range(len(t)):
    t_.append(float(t[i]))
    x_.append(float(x1[i]))    
   
    
t_ = np.array(t_)
x_ = np.array(x_)

# %%
dt = t_[1] - t_[0]
fs = 1/ dt

# %%
x=x_[:]
t1=t_[:]

# %%
plt.plot(x_)

# %%
plt.plot(t, x - np.mean(x))
plt.xticks([])
# Out:
# ([], [])

# %%
# x1 = 7*np.sin(1*2*np.pi*t1) + 3*np.sin(5*2*np.pi*t1) + np.sin(9*2*np.pi*t1)

# %%
imfm = emd.sift.mask_sift(x)
n_imfm= len(imfm[0,:])
# Out:
#  Inputs samples (120) is small for specified max_imfs (9) very likely that 5 or fewer imfs are returned

# %%
# plt.figure(figsize=(12,12))

for i in range(n_imfm):
    plt.subplot(n_imfm,1,i +1)
    plt.plot(t1,imfm[:,i])
    
    plt.subplots_adjust(wspace=0, hspace=0)
    
# plt.savefig('results/'+dir_+'/imfs.png')

# %%
Em=[]
Pm=[]
for i in range(n_imfm-1):
    E = mean(imfm[:,i]**2)
    P = len(imfm[:,i])/bm(imfm[:,i])
    Em.append(E)
    Pm.append(P)
    
Ex=mean(x**2)
Px=2*len(x)/bm(x)

Em=np.array(Em)
Pm=np.array(Pm)

# %%
Pm
# Out:
# array([ 4.13793103, 12.        , 20.        , 40.        ])

# %%
lf, slope, L, U = bypart(x1,Pm,Em,0,n_imfm,3.646)
plt.title('Least square fit')
plt.plot(lf[0],lf[1],'--',color='black',linewidth=1)
plt.plot((lf[0])[:],U[:],c='black',linestyle='--')
plt.plot((lf[0])[:],L[:],c='black',linestyle='--')

plt.scatter((Pm),(Em),color='blue',s=80)
print(slope)

plt.loglog()
plt.axvline(x=.4*len(x1),linestyle='--')
# plt.ylim(1e4)
# Out:
# 65508.763483300194

# %%
trend = 5

# %%
x2 = x

# %%
fxx, pxx = sp.signal.welch(x2,fs,window='boxcar', nperseg=len(x2))
non_zero_indices = fxx != 0

period = 1 / fxx[non_zero_indices]


popt, pcov = curve_fit(scaling,period, pxx[non_zero_indices])
print(popt)

sig=np.std(pxx)
prd=np.linspace(min(period),max(period),1000)

plt.plot(period,pxx[non_zero_indices],c='black')
plt.axvline(x=.4*len(x),linestyle='--')

lf=log_fit(period,pxx[non_zero_indices],prd,1)
plt.plot(lf[0],lf[1],color='red')
plt.plot(lf[0], lf[1]*1*(sig),color='red',linestyle='--')
plt.loglog()
# Out:
# [1.31511601e+04 3.26248229e+00]
# []

# %%
period
# Out:
# array([24.008784  , 12.004392  ,  8.002928  ,  6.002196  ,  4.8017568 ,
#         4.001464  ,  3.42982629,  3.001098  ,  2.66764267,  2.4008784 ,
#         2.18261673,  2.000732  ,  1.84682954,  1.71491314,  1.6005856 ,
#         1.500549  ,  1.41228141,  1.33382133,  1.26362021,  1.2004392 ,
#         1.14327543,  1.09130836,  1.04386017,  1.000366  ,  0.96035136,
#         0.92341477,  0.88921422,  0.85745657,  0.8278891 ,  0.8002928 ,
#         0.7744769 ,  0.7502745 ,  0.72753891,  0.70614071,  0.68596526,
#         0.66691067,  0.64888605,  0.63181011,  0.61560985,  0.6002196 ,
#         0.5855801 ,  0.57163771,  0.55834381,  0.54565418,  0.53352853,
#         0.52193009,  0.51082519,  0.500183  ,  0.48997518,  0.48017568,
#         0.47076047,  0.46170738,  0.45299592,  0.44460711,  0.43652335,
#         0.42872829,  0.42120674,  0.41394455,  0.40692854,  0.4001464 ])

# %%
# plt.figure(figsize=(10,6))

fxx, pxx =sp.signal.welch(x2,fs,detrend='linear',window='boxcar', nperseg=len(x2))
plt.plot(1/fxx,pxx)
p0=.05
y0= scargle(p0,fxx,pxx)
plt.axhline(y=y0,color='blue')
plt.axvline(x=.4*len(x),linestyle='--')


plt.semilogx()
# plt.ylim(0,2*y0)
# plt.savefig('results/'+dir_+'/periodogram.png')
# Out:
# []

# %%
1/fxx
# Out:
# array([        inf, 24.008784  , 12.004392  ,  8.002928  ,  6.002196  ,
#         4.8017568 ,  4.001464  ,  3.42982629,  3.001098  ,  2.66764267,
#         2.4008784 ,  2.18261673,  2.000732  ,  1.84682954,  1.71491314,
#         1.6005856 ,  1.500549  ,  1.41228141,  1.33382133,  1.26362021,
#         1.2004392 ,  1.14327543,  1.09130836,  1.04386017,  1.000366  ,
#         0.96035136,  0.92341477,  0.88921422,  0.85745657,  0.8278891 ,
#         0.8002928 ,  0.7744769 ,  0.7502745 ,  0.72753891,  0.70614071,
#         0.68596526,  0.66691067,  0.64888605,  0.63181011,  0.61560985,
#         0.6002196 ,  0.5855801 ,  0.57163771,  0.55834381,  0.54565418,
#         0.53352853,  0.52193009,  0.51082519,  0.500183  ,  0.48997518,
#         0.48017568,  0.47076047,  0.46170738,  0.45299592,  0.44460711,
#         0.43652335,  0.42872829,  0.42120674,  0.41394455,  0.40692854,
#         0.4001464 ])

# %% [markdown]
# ###
