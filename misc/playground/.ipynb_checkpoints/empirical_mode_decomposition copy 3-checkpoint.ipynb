# %% [markdown]
# ### import all necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import emd

# %%
from scipy import signal, ndimage
from scipy.signal import hilbert, chirp
from statistics import mean

# %%
import plotly.graph_objects as go
import plotly.express as px

# %%
import scienceplots
plt.style.use(['science','notebook','grid'])

# %% [markdown]
# ### ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### enter the file

# %%
name= input('enter file: ')
# Out:
# enter file:  inttime_har060_1848km

# %% [markdown]
# parameters of the signal

# %%
df=pd.read_csv('../datasets/'+name+'.csv')
t1=df['timestamps']
wp1=df['ls']
x=np.array(wp1)

dt= t1[1]-t1[0]
fs= 1/dt

# %%
fs
# Out:
# 3.158057060975039

# %% [markdown]
# ### ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### plotting settings

# %%
# plt.rcParams['lines.linewidth']=2
# plt.rcParams["grid.alpha"]=0.3
# plt.rcParams[ 'grid.color']='w' 
# plt.rcParams['grid.linestyle']= '-'
# plt.rcParams['grid.linewidth']=1
# plt.rcParams['figure.figsize']= [8,4]
# plt.rcParams.update({'font.size':18})
# plt.style.use('dark_background')
# plt.rcParams['axes.grid']=True

# %% [markdown]
# ### ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### the original signal

# %%
plt.figure(figsize=(10,4))
plt.plot(t1,x, '-', color='brown', lw=2, label='signl')
plt.xlabel('time [t]')
plt.ylabel('Voltage [v]')
plt.legend(loc='lower left', fontsize=14)

# %% [markdown]
# ### ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### EMD

# %%
x=np.array(wp1)

# %%
imf = emd.sift.sift(x)

# %%
# Get the default configuration for a sift
config = emd.sift.get_config('sift')
# Adjust the threshold for accepting an IMF
config['imf_opts/sd_thresh'] = 0.05
config['extrema_opts/method'] = 'rilling'

imf = emd.sift.sift(x)

# emd.plotting.plot_imfs(imf)

# %%
# Extract the options for get_next_imf - these can be customised here at this point.
imf_opts = config['imf_opts']

# Extract first IMF from the signal
imf1, continue_sift = emd.sift.get_next_imf(x[:, None],           **imf_opts)

# Extract second IMF from the signal with the first IMF removed
imf2, continue_sift = emd.sift.get_next_imf(x[:, None]-imf1,      **imf_opts)

# Extract third IMF from the signal with the first and second IMFs removed
imf3, continue_sift = emd.sift.get_next_imf(x[:, None]-imf1-imf2, **imf_opts)

imf4, continue_sift = emd.sift.get_next_imf(x[:, None]-imf1-imf2-imf3, **imf_opts)

imf5, continue_sift = emd.sift.get_next_imf(x[:, None]-imf1-imf2-imf3-imf4, **imf_opts)


# The residual is the signal component left after removing the IMFs
residual = x[:, None] - imf1 - imf2 - imf3-imf4-imf5

# Contactenate our IMFs into one array
imfs_manual = np.c_[imf1, imf2, imf3,imf4,imf5, residual]

# Visualise
# emd.plotting.plot_imfs(imfs_manual)

# %%
def list_corrector(l):
    l_=[]
    for i in range(len(l)):
        l_.append(l[i][0])
    return np.array(l_)

# %%
imf1=list_corrector(imf1)
imf2=list_corrector(imf2)
imf3=list_corrector(imf3)
imf4=list_corrector(imf4)

# %% [markdown]
# ### ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### the imfs

# %%
plt.figure(figsize=(10,4))
plt.plot(t1,imf3, '-', color='brown', lw=2, label='imf 1')
# plt.plot(t1,x, '-', color='green', lw=3, label='imf 1')

plt.xlabel('time [t]')
plt.ylabel('Voltage [v]')
plt.legend(loc='lower left', fontsize=14)

# %%
fig=px.line(x=t1,y=imf4,template='plotly_dark')
fig.update_layout(
    autosize=False,
    width=800,
    height=400,)
fig.show()

# %% [markdown]
# ### ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Hilbert Transform

# %%
# Compute frequency statistics
IP, IF, IA = emd.spectra.frequency_transform(imf, fs, 'hilbert')

# %%
plt.figure(figsize=(10,5))
plt.legend()
plt.plot(t1,IF[:,2])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
IF_1=[]
for i in IF:
    IF_1.append(i[0])
IF_2=[]
for i in IF:
    IF_2.append(i[1])
IF_3=[]
for i in IF:
    IF_3.append(i[2])
IF_4=[]
for i in IF:
    IF_4.append(i[3])

# %%
print(mean(IF_4))
print(mean(IF_3))
print(mean(IF_2))
print(mean(IF_1))
# Out:
# -0.0003583445991104832
# 0.09997089672561948
# 0.16562041884215165
# 0.3946991708404836

# %%
print((mean(IF_4)+mean(IF_3)+mean(IF_2)+mean(IF_1))/4)
# Out:
# 0.16498303545228607

# %%
fig=px.line(y=IF_2,x=t1,template="plotly_dark")
fig.update_layout(
    autosize=False,
    width=800,
    height=400,)
fig.show()

# %%
f, pxx =sp.signal.welch(imf2+imf3+imf4,fs,nperseg=92)
fig=px.line(x=f,y=pxx, template='plotly_dark')
fig.update_layout(
    autosize=False,
    width=800,
    height=400,)
fig.show()

# %%
f, pxx =sp.signal.welch(imf2,fs,nperseg=92)
plt.scatter(f,pxx,marker='+',s=100)

# %%
plt.scatter(t1,IF_4, marker='+')

# %%
plt.scatter(t1,IP[:,1], marker='+',s=100)

# %%
max(IA[:,1])
# Out:
# 0.3112846535830485

# %%
freq_range = (0, 1, 100)
hht_f0, spec0 = emd.spectra.hilberthuang(IF[:,0], IA[:,0],freq_range)
hht_f1, spec1 = emd.spectra.hilberthuang(IF[:,1], IA[:,1],freq_range)
hht_f2, spec2 = emd.spectra.hilberthuang(IF[:,2], IA[:,2],freq_range)
hht_f3, spec3 = emd.spectra.hilberthuang(IF[:,3], IA[:,3],freq_range)

hht_f, spec = emd.spectra.hilberthuang(IF, IA,freq_range)


plt.plot(hht_f0, spec0)
plt.plot(hht_f1, spec1)
plt.plot(hht_f2, spec2)
plt.plot(hht_f3, spec3)

plt.legend(['1','2','3','4'], frameon=False)
plt.xlim(0.05, 1)
plt.ylim(0, max(spec1))

plt.xlabel('Frequency (Hz)')
plt.ylabel('Power')
# Out:
# Text(0, 0.5, 'Power')

# %%
hht_f234, spec234 = emd.spectra.hilberthuang(IF[:,1]+IF[:,2], IA[:,1]+IA[:,2],freq_range)
# hht_f234, spec234 = emd.spectra.hilberthuang(IF, IA,freq_range)

# %%
plt.step(hht_f234,  spec234)
plt.step(hht_f1, spec1)

# %%
fig=px.line(y=spec1,x=hht_f1,template="presentation")
fig.update_layout(
    autosize=False,
    width=800,
    height=400,)
fig.show()

# %%
fig=px.line(x=hht_f0,y=spec0, template='plotly_dark',range_x=(.05,.8), range_y=(0,.25))
fig.update_layout(
    autosize=False,
    width=600,
    height=400,)
fig.show()

# %%
IP, IF, IA = emd.spectra.frequency_transform(imf, fs, 'nht')
plt.figure(figsize=(8, 4))

plt.subplot(121)
# Plot a simple histogram using frequency bins from 0-.5Hz
plt.hist(IF[:, 1], np.linspace(0, .5,20))
plt.grid(True)
plt.title('IF Histogram')
plt.xlabel('Frequency (Hz)')

plt.subplot(122)
# Plot an amplitude-weighted histogram using frequency bins from 0-.5Hz
plt.hist(IF[:, 1], np.linspace(0, .5,20), weights=IA[:, 1])
plt.grid(True)
plt.title('IF Histogram\nweighted by IA')
plt.xlabel('Frequency (Hz)')
# Out:
# Text(0.5, 0, 'Frequency (Hz)')

# %%
IP, IF, IA = emd.spectra.frequency_transform(imf, fs, 'nht')
freq_range = (0, 1, 100)
hht_f, hht = emd.spectra.hilberthuang(IF, IA, freq_range, mode='amplitude', sum_time=False)
hht = ndimage.gaussian_filter(hht, .5)
plt.figure(figsize=(10,5))

c=plt.pcolormesh(t1, hht_f, hht, cmap='binary')
plt.title('Hilbert-Huang Transform')
plt.xlabel('Time (mi)')
plt.ylabel('Frequency (Hz)')
plt.colorbar(c)
# Out:
# /var/folders/gq/8wbg8lhd50b6xp31434c79mh0000gn/T/ipykernel_65287/1695282727.py:7: MatplotlibDeprecationWarning:
#
# Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#
# /var/folders/gq/8wbg8lhd50b6xp31434c79mh0000gn/T/ipykernel_65287/1695282727.py:11: MatplotlibDeprecationWarning:
#
# Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.

# %%
plt.figure(figsize=(8,5))
plt.plot(t1,IF[:,0])

plt.plot(t1,IF[:,1])
plt.plot(t1,IF[:,2])

# %%
imfm = emd.sift.mask_sift(x)
# Out:
#  Inputs samples (92) is small for specified max_imfs (9) very likely that 5 or fewer imfs are returned

# %%
IPm, IFm, IAm = emd.spectra.frequency_transform(imfm, fs, 'nht')
freq_range = (0, 1, 100)
hht_f, hht = emd.spectra.hilberthuang(IFm, IAm, freq_range, mode='amplitude', sum_time=False)
hht = ndimage.gaussian_filter(hht, 1)
plt.figure(figsize=(10,5))

c= plt.pcolormesh(t1, hht_f, hht, cmap='binary')
plt.title('Hilbert-Huang Transform')
plt.xlabel('Time (seconds)')
plt.ylabel('Frequency (Hz)')
plt.colorbar(c)
# Out:
# /var/folders/gq/8wbg8lhd50b6xp31434c79mh0000gn/T/ipykernel_65287/2522927869.py:7: MatplotlibDeprecationWarning:
#
# Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#
# /var/folders/gq/8wbg8lhd50b6xp31434c79mh0000gn/T/ipykernel_65287/2522927869.py:11: MatplotlibDeprecationWarning:
#
# Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.

# %%
np.size(hht)
# Out:
# 9200

# %%
temp=['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 
   'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 
   'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 
   'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r',
   'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 
   'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 
   'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 
   'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 
   'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern',
   'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 
   'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r',
   'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 
   'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 
   'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r']

# %% [markdown]
# ## Relevance and Quality of IMFs

# %%
c_i=imf1

# %%
def quality(c_i):
    a,b,c=0,0,0
    for n in range(len(t1)):
        a+= x[n]*c_i[n]
        b+= x[n]**2
        c+= c_i[n]**2

    gamma= a/(np.sqrt(b*c))
    return gamma

# %%
print(quality(imf4))
print(quality(imf3))
print(quality(imf2))
print(quality(imf1))

print(quality(imf2+imf3+imf4))
# Out:
# 0.9674314984475295
# 0.06374746059180077
# 0.2612594427919379
# 0.20139620644823975
# 0.9839889815135727

# %%
import plotly.figure_factory as ff
colorscale=

# %%
plt.plot(t1,IF[:,1])
